# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Read the image
img = cv2.imread("faktura.jpg", 0)
 
# Thresholding the image
(thresh, img_bin) = cv2.threshold(img, 128, 255,cv2.THRESH_BINARY|     cv2.THRESH_OTSU)
# Invert the image
img_bin = 255-img_bin

# %%
Image.fromarray(img_bin)
# Out:
# <PIL.Image.Image image mode=L size=1700x2338 at 0x7F797D9FAFD0>

# %%
# Defining a kernel length
kernel_length = np.array(img).shape[1]//80
 
# A verticle kernel of (1 X kernel_length), which will detect all the verticle lines from the image.
verticle_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, kernel_length))
# A horizontal kernel of (kernel_length X 1), which will help to detect all the horizontal line from the image.
hori_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_length, 1))
# A kernel of (3 X 3) ones.
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))

# %%
img_temp2 = cv2.erode(img_bin, hori_kernel, iterations=3)
horizontal_lines_img = cv2.dilate(img_temp2, hori_kernel, iterations=3)
Image.fromarray(horizontal_lines_img)
# Out:
# <PIL.Image.Image image mode=L size=1700x2338 at 0x7F7978D5DB70>

# %%
test.max()
# Out:
# 1.0

# %%
test = np.sum(horizontal_lines_img / (horizontal_lines_img.max()/1.0), axis=1)

# %%
lines_rows = []
for i, row in enumerate(test):
    if row > 500:
        lines_rows.append(i)

# %%
lines_rows =
# Out:
# [852, 853, 854, 855, 918, 919, 920, 921, 1267, 1268, 1269, 1333, 1334, 1335]

# %%
img_bin.shape
# Out:
# (2338, 1700)

# %%
table = img_bin[lines_rows[0]-50:lines_rows[-1]+50, 0:img_bin.shape[1]]

# %%
Image.fromarray(table)
# Out:
# <PIL.Image.Image image mode=L size=1700x583 at 0x7F79499D2FD0>
